# %% [markdown]
# # Quick Notebook interfacing with plotly graph objects to show my conference participation for 2024

# %% [markdown]
# ### Notebook by Solomon Sonya
# ##### Code augmented using ChatGPT

# %%
import plotly.graph_objects as go

# Create figure
fig = go.Figure()

# Existing markers with updated legend names
fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[-115.1398],  # Las Vegas
    lat=[36.1699],
    text=["DEFCON"],
    marker={'size': 12, 'color': 'red'},
    textposition="top right",
    name="DEFCON",  # Legend name
    showlegend=True  # Show in legend
))

fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[-79.3832],  # Toronto
    lat=[43.6532],
    text=["BlackHat SecTor"],
    marker={'size': 12, 'color': 'blue'},
    textposition="top right",
    name="BlackHat",  # Legend name
    showlegend=True  # Show in legend
))

fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[-85.6681],  # Grand Rapids
    lat=[42.9634],
    text=["GrrCon"],
    marker={'size': 12, 'color': 'green'},
    textposition="top right",
    name="GrrCon",  # Legend name
    showlegend=True  # Show in legend
))

fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[-84.3880],  # Atlanta
    lat=[33.7490],
    text=["HackerHalted"],
    marker={'size': 12, 'color': 'purple'},
    textposition="top right",
    name="HackerHalted",  # Legend name
    showlegend=True  # Show in legend
))

fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[-111.8910],  # Salt Lake City
    lat=[40.7608],
    text=["SANS DFIR Summit - Virtual"],
    marker={'size': 12, 'color': 'orange'},
    textposition="top right",
    name="SANS DFIR",  # Legend name
    showlegend=True  # Show in legend
))

fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[-122.2585],  # Berkeley
    lat=[37.8715],
    text=["ACTION"],
    marker={'size': 12, 'color': 'brown'},
    textposition="top right",
    name="ACTION",  # Legend name
    showlegend=True  # Show in legend
))

fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[2.3522],  # Paris
    lat=[48.8566],
    text=["LeHack"],
    marker={'size': 12, 'color': 'cyan'},
    textposition="top right",
    name="LeHack",  # Legend name
    showlegend=True  # Show in legend
))

# New marker for Sec-T in Stockholm
fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[18.0686],  # Stockholm
    lat=[59.3293],
    text=["Sec-T"],
    marker={'size': 12, 'color': 'magenta'},
    textposition="top right",
    name="Sec-T",  # Legend name
    showlegend=True  # Show in legend
))

# New marker for DEFCON Area41 in Zurich
fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[8.5417],  # Zurich
    lat=[47.3769],
    text=["DEFCON Area41"],
    marker={'size': 12, 'color': 'lightblue'},
    textposition="top right",
    name="DEFCON Area41",  # Legend name
    showlegend=True  # Show in legend
))

# New marker for PMRI at Purdue University
fig.add_trace(go.Scattermapbox(
    mode="markers+text",
    lon=[-87.0120],  # Purdue University
    lat=[40.4237],
    text=["PMRI"],
    marker={'size': 12, 'color': 'orange'},
    textposition="top right",
    name="PMRI",  # Legend name
    showlegend=True  # Show in legend
))

# Lines connecting PMRI to all other markers
# Setting showlegend to False for the line traces
fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, -115.1398],  # PMRI to Las Vegas
    lat=[40.4237, 36.1699],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, -79.3832],  # PMRI to Toronto
    lat=[40.4237, 43.6532],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, -85.6681],  # PMRI to Grand Rapids
    lat=[40.4237, 42.9634],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, -84.3880],  # PMRI to Atlanta
    lat=[40.4237, 33.7490],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, -111.8910],  # PMRI to Salt Lake City
    lat=[40.4237, 40.7608],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, -122.2585],  # PMRI to Berkeley
    lat=[40.4237, 37.8715],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, 2.3522],  # PMRI to Paris
    lat=[40.4237, 48.8566],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, 18.0686],  # PMRI to Stockholm
    lat=[40.4237, 59.3293],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

fig.add_trace(go.Scattermapbox(
    mode="lines",
    lon=[-87.0120, 8.5417],  # PMRI to Zurich
    lat=[40.4237, 47.3769],
    line=dict(width=1, color='black'),
    showlegend=False  # Hide from legend
))

# Update layout with map settings
fig.update_layout(
    margin={'l': 0, 't': 0, 'b': 0, 'r': 0},
    mapbox={
        'center': {'lon': -50, 'lat': 40},
        'style': "open-street-map",
        'zoom': 2.5}, 
    height=800,  # Set the height of the figure
    width=1400   # Set the width of the figure
)

fig.show()
